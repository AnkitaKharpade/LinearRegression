# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

import warnings
warnings.filterwarnings('ignore')

# %%
df=pd.read_csv(r"C:\Users\HP\Downloads\Healthcaredatasets.csv")
df
# Out:
#                     Name  Age  Gender Blood Type Medical Condition  \
# 0          Bobby JacksOn   30    Male         B-            Cancer
# 1           LesLie TErRy   62    Male         A+            Cancer
# 2            DaNnY sMitH   76  Female         A-            Cancer
# 3           andrEw waTtS   28  Female         O+            Cancer
# 4          adrIENNE bEll   43  Female        AB+            Cancer
# ..                   ...  ...     ...        ...               ...
# 195        Mark lAWrencE   19  Female         O-            Cancer
# 196           JOhN eLlis   83  Female         A-            Cancer
# 197  MRs. TiFFAny DeNnIs   26    Male         O-            Cancer
# 198        cyNTHIa HuANG   51    Male         O+            Cancer
# 199     meLiSSA LawRENcE   20    Male         O+            Cancer
#
#             Hospital  Billing Amount  Room Number  Test Results
# 0    Sons and Miller     18856.28131          328        Normal
# ...

# %%
df.shape
# Out:
# (200, 9)

# %%
df.head()
# Out:
#             Name  Age  Gender Blood Type Medical Condition         Hospital  \
# 0  Bobby JacksOn   30    Male         B-            Cancer  Sons and Miller
# 1   LesLie TErRy   62    Male         A+            Cancer  Sons and Miller
# 2    DaNnY sMitH   76  Female         A-            Cancer  Sons and Miller
# 3   andrEw waTtS   28  Female         O+            Cancer  Sons and Miller
# 4  adrIENNE bEll   43  Female        AB+            Cancer  Sons and Miller
#
#    Billing Amount  Room Number  Test Results
# 0     18856.28131          328        Normal
# 1     33643.32729          265  Inconclusive
# 2     27955.09608          205        Normal
# 3     37909.78241          450      Abnormal
# 4     14238.31781          458      Abnormal

# %%
df.tail()
# Out:
#                     Name  Age  Gender Blood Type Medical Condition  \
# 195        Mark lAWrencE   19  Female         O-            Cancer
# 196           JOhN eLlis   83  Female         A-            Cancer
# 197  MRs. TiFFAny DeNnIs   26    Male         O-            Cancer
# 198        cyNTHIa HuANG   51    Male         O+            Cancer
# 199     meLiSSA LawRENcE   20    Male         O+            Cancer
#
#             Hospital  Billing Amount  Room Number  Test Results
# 195  Sons and Miller     10348.81852          271  Inconclusive
# 196  Sons and Miller     14371.53970          341  Inconclusive
# 197  Sons and Miller     13769.40313          498      Abnormal
# 198  Sons and Miller     35868.53864          309      Abnormal
# 199  Sons and Miller     35205.28460          104      Abnormal

# %%
df.describe()
# Out:
#               Age  Billing Amount  Room Number
# count  200.000000      200.000000   200.000000
# mean    49.885000    24779.185953   296.570000
# std     20.939054    14370.893894   117.855312
# min     18.000000     -502.507813   102.000000
# 25%     30.000000    12498.436065   207.250000
# 50%     51.500000    23749.801450   293.000000
# 75%     67.000000    36118.835415   405.250000
# max     85.000000    50142.026950   500.000000

# %%
sns.displot(df.Age);

# %%
df.columns
# Out:
# Index(['Name', 'Age', 'Gender', 'Blood Type', 'Medical Condition', 'Hospital',
#        'Billing Amount', 'Room Number', 'Test Results'],
#       dtype='object')

# %%
df.columns=['Name', 'Age', 'Gender', 'Blood Type', 'Medical Condition', 'Hospital',
       'BillingAmount', 'Room Number', 'Test Results']

# %%
df
# Out:
#                     Name  Age  Gender Blood Type Medical Condition  \
# 0          Bobby JacksOn   30    Male         B-            Cancer
# 1           LesLie TErRy   62    Male         A+            Cancer
# 2            DaNnY sMitH   76  Female         A-            Cancer
# 3           andrEw waTtS   28  Female         O+            Cancer
# 4          adrIENNE bEll   43  Female        AB+            Cancer
# ..                   ...  ...     ...        ...               ...
# 195        Mark lAWrencE   19  Female         O-            Cancer
# 196           JOhN eLlis   83  Female         A-            Cancer
# 197  MRs. TiFFAny DeNnIs   26    Male         O-            Cancer
# 198        cyNTHIa HuANG   51    Male         O+            Cancer
# 199     meLiSSA LawRENcE   20    Male         O+            Cancer
#
#             Hospital  BillingAmount  Room Number  Test Results
# 0    Sons and Miller    18856.28131          328        Normal
# ...

# %%
sns.displot(df.BillingAmount);

# %%
sns.displot(df.Gender);

# %%
df.columns=['Name', 'Age', 'Gender', 'BloodType', 'MedicalCondition', 'Hospital',
       'BillingAmount', 'RoomNumber', 'TestResults']

# %%
df
# Out:
#                     Name  Age  Gender BloodType MedicalCondition  \
# 0          Bobby JacksOn   30    Male        B-           Cancer
# 1           LesLie TErRy   62    Male        A+           Cancer
# 2            DaNnY sMitH   76  Female        A-           Cancer
# 3           andrEw waTtS   28  Female        O+           Cancer
# 4          adrIENNE bEll   43  Female       AB+           Cancer
# ..                   ...  ...     ...       ...              ...
# 195        Mark lAWrencE   19  Female        O-           Cancer
# 196           JOhN eLlis   83  Female        A-           Cancer
# 197  MRs. TiFFAny DeNnIs   26    Male        O-           Cancer
# 198        cyNTHIa HuANG   51    Male        O+           Cancer
# 199     meLiSSA LawRENcE   20    Male        O+           Cancer
#
#             Hospital  BillingAmount  RoomNumber   TestResults
# 0    Sons and Miller    18856.28131         328        Normal
# ...

# %%
sns.displot(df.Age);

# %%
sns.displot(df.TestResults);

# %%
sns.jointplot(x='RoomNumber',y='Age',data=df,kind='reg')

# %%
df.corr()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[35], line 1
# ----> 1 df.corr()
#
# File C:\ProgramData\anaconda33\Lib\site-packages\pandas\core\frame.py:11049, in DataFrame.corr(self, method, min_periods, numeric_only)
#   11047 cols = data.columns
#   11048 idx = cols.copy()
# > 11049 mat = data.to_numpy(dtype=float, na_value=np.nan, copy=False)
#   11051 if method == "pearson":
#   11052     correl = libalgos.nancorr(mat, minp=min_periods)
#
# File C:\ProgramData\anaconda33\Lib\site-packages\pandas\core\frame.py:1993, in DataFrame.to_numpy(self, dtype, copy, na_value)
#    1991 if dtype is not None:
#    1992     dtype = np.dtype(dtype)
# -> 1993 result = self._mgr.as_array(dtype=dtype, copy=copy, na_value=na_value)
#    1994 if result.dtype is not dtype:
#    1995     result = np.asarray(result, dtype=dtype)
#
# ...

# %%
sns.pairplot(df)

# %%
sns.heatmap(df.corr(),annot=True);
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[37], line 1
# ----> 1 sns.heatmap(df.corr(),annot=True)
#
# File C:\ProgramData\anaconda33\Lib\site-packages\pandas\core\frame.py:11049, in DataFrame.corr(self, method, min_periods, numeric_only)
#   11047 cols = data.columns
#   11048 idx = cols.copy()
# > 11049 mat = data.to_numpy(dtype=float, na_value=np.nan, copy=False)
#   11051 if method == "pearson":
#   11052     correl = libalgos.nancorr(mat, minp=min_periods)
#
# File C:\ProgramData\anaconda33\Lib\site-packages\pandas\core\frame.py:1993, in DataFrame.to_numpy(self, dtype, copy, na_value)
#    1991 if dtype is not None:
#    1992     dtype = np.dtype(dtype)
# -> 1993 result = self._mgr.as_array(dtype=dtype, copy=copy, na_value=na_value)
#    1994 if result.dtype is not dtype:
#    1995     result = np.asarray(result, dtype=dtype)
#
# ...

# %%
X=df[['Age','RoomNumber']]
X.head()
# Out:
#    Age  RoomNumber
# 0   30         328
# 1   62         265
# 2   76         205
# 3   28         450
# 4   43         458

# %%
Y=df['BillingAmount']
Y
# Out:
# 0      18856.28131
# 1      33643.32729
# 2      27955.09608
# 3      37909.78241
# 4      14238.31781
#           ...
# 195    10348.81852
# 196    14371.53970
# 197    13769.40313
# 198    35868.53864
# 199    35205.28460
# Name: BillingAmount, Length: 200, dtype: float64

# %%
X.shape
# Out:
# (200, 2)

# %%
X=df[['Age','RoomNumber']]
Y=df['BillingAmount']
from sklearn.model_selection import train_test_split
X_train,X_test,Y_train,Y_test=train_test_split(X,Y,test_size=0.4)

# %%
X_train.shape
# Out:
# (120, 2)

# %%
X_test.shape
# Out:
# (80, 2)

# %%
Y_train.shape
# Out:
# (120,)

# %%
Y_test.shape
# Out:
# (80,)

# %%
X_train.head()
# Out:
#      Age  RoomNumber
# 22    58         327
# 151   21         267
# 117   37         326
# 26    51         401
# 50    30         456

# %%
X_test.head()
# Out:
#      Age  RoomNumber
# 39    57         272
# 83    44         410
# 120   22         178
# 27    34         157
# 85    80         395

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
import pandas as pd
import matplotlib.pyplot as plt

X=df[['Age','RoomNumber']]
Y=df['BillingAmount']
#spliting the model

X_train,X_test,Y_train,Y_test=train_test_split(X,Y,test_size=0.4)

#Train the Model
model=LinearRegression()
model.fit(X_train,Y_train)

#predict 
Y_pred=model.predict(X_test)


#plot
Y_pred=model.predict(X_test)
plt.figure(figsize=(8,6))
plt.scatter(Y_test,Y_pred,color='blue',edgecolor='k',alpha=0.7)
plt.xlabel('Age')
plt.ylabel('BillingAmount')
plt.title("Age v/s BillingAmount using Linear Regression")
plt.plot([Y_test.min(),Y_test.max()],[Y_test.min(),Y_test.max()],color='red',linewidth=2)
plt.grid(True)
plt.show()
